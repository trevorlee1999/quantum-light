# %%
import numpy as np
import pathlib
import pyvisa
import time
import matplotlib.pyplot as plt
import math
from datetime import datetime
TODAY_STR = datetime.now().strftime("%Y%m%d")
print(f"\x1b[1;3;4;96mDate of running the code:\x1b[0m \x1b[1;3;4;92m{TODAY_STR}\x1b[0m")
# Out:
# Date of running the code: 20241101

# %%
CHIP_ID = f"Freespace-{TODAY_STR}"
FEATURE_ID = "new_GRIN_Groove_with_YSO_crystal_0.005E_-10DbMr"

PM_RANGE = 10

# FEATURE_ID = 'col2_row_ring_top_weirdcoupling'
print(f"{CHIP_ID} {FEATURE_ID} {PM_RANGE}")
# Out:
# Freespace-20241016 new_GRIN_Groove_with_YSO_crystal_0.005E_-10DbMr 10

# %%
grating_file_name = pathlib.Path(f"{CHIP_ID}_{FEATURE_ID}.npz")
if grating_file_name.is_file():
    print("Found existing file. Plotting...")
    grating_input_data = np.load(grating_file_name)
    data_arr_cut = grating_input_data["data_arr_cut"]
    wav_arr = grating_input_data["wav_arr"]
    del grating_input_data
    plt.close()
    plt.plot(wav_arr, data_arr_cut)
    plt.grid()
    plt.xlabel("wavelength (nm)")
    plt.ylabel("voltage (V)")
    plt.title(f"{CHIP_ID}_{FEATURE_ID} transmission")
    plt.annotate(
        f"Power meter range: {PM_RANGE} dBm",
        (0.15, 0.75),
        xycoords="axes fraction",
        alpha=0.6,
        fontsize=12,
        fontfamily="monospace",
    )
    plt.show()
else:
    print("\x1b[0;93mNo existing file found. Proceeding...\x1b[0m")
# Out:
# No existing file found. Proceeding...

# %%
rm = pyvisa.ResourceManager()
rm.list_resources()
# Out:
# ('TCPIP::169.254.112.67::INSTR',
#  'TCPIP::169.254.112.67::INSTR',
#  'TCPIP::169.254.112.67::INSTR',
#  'TCPIP::169.254.112.67::INSTR')

# %%
is_connect_success = False 
while not is_connect_success:
    try:
        DSO = rm.open_resource("TCPIP0::169.254.82.2::inst0::INSTR")
        print(DSO.query("*IDN?"))
        print("\x1b[0;92mDSO Connection established.\x1b[0m")
        is_connect_success = True
    except pyvisa.VisaIOError:
        print("Retrying...")
        time.sleep(0.5)
# Out:
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# Retrying...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 while not is_connect_success:
#       3     try:
# ----> 4         DSO = rm.open_resource("TCPIP0::169.254.82.2::inst0::INSTR")
#       5         print(DSO.query("*IDN?"))
#       6         print("\x1bDSO Connection established.\x1b")
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\highlevel.py:3292, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3286     if not present:
#    3287         raise ValueError(
#    3288             "%r is not a valid attribute for type %s"
#    3289             % (key, res.__class__.__name__)
#    3290         )
# -> 3292 res.open(access_mode, open_timeout)
#    3294 for key, value in kwargs.items():
#    3295     setattr(res, key, value)
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\resources\resource.py:281, in Resource.open(self, access_mode, open_timeout)
#     277 logger.debug("%s - opening ...", self._resource_name, extra=self._logging_extra)
#     278 with self._resource_manager.ignore_warning(
#     279     constants.StatusCode.success_device_not_present
#     280 ):
# --> 281     self.session, status = self._resource_manager.open_bare_resource(
#     282         self._resource_name, access_mode, open_timeout
#     283     )
#     285     if status == constants.StatusCode.success_device_not_present:
#     286         # The device was not ready when we opened the session.
#     287         # Now it gets five seconds more to become ready.
#     288         # Every 0.1 seconds we probe it with viClear.
#     289         start_time = time.time()
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\highlevel.py:3217, in ResourceManager.open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3188 def open_bare_resource(
#    3189     self,
#    3190     resource_name: str,
#    3191     access_mode: constants.AccessModes = constants.AccessModes.no_lock,
#    3192     open_timeout: int = constants.VI_TMO_IMMEDIATE,
#    3193 ) -> Tuple[VISASession, StatusCode]:
#    3194     """Open the specified resource without wrapping into a class.
#    3195
#    3196     Parameters
#    (...)
#    3215
#    3216     """
# -> 3217     return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\highlevel.py:168, in PyVisaLibrary.open(self, session, resource_name, access_mode, open_timeout)
#     159     return (
#     160         VISASession(0),
#     161         self.handle_return_value(None, StatusCode.error_invalid_resource_name),
#     162     )
#     164 cls = sessions.Session.get_session_class(
#     165     parsed.interface_type_const, parsed.resource_class
#     166 )
# --> 168 sess = cls(session, resource_name, parsed, open_timeout)
#     170 return self._register(sess), StatusCode.success
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\tcpip.py:86, in TCPIPInstrSession.__new__(cls, resource_manager_session, resource_name, parsed, open_timeout)
#      83 else:
#      84     newcls = TCPIPInstrVxi11
# ---> 86 return newcls(resource_manager_session, resource_name, parsed, open_timeout)
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\sessions.py:322, in Session.__init__(self, resource_manager_session, resource_name, parsed, open_timeout)
#     319 default_timeout = attributes.AttributesByID[attr].default
#     320 self.set_attribute(attr, default_timeout)
# --> 322 self.after_parsing()
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\tcpip.py:457, in TCPIPInstrVxi11.after_parsing(self)
#     455     port = None
#     456 try:
# --> 457     self.interface = Vxi11CoreClient(host_address, port, self.open_timeout)
#     458 except rpc.RPCError:
#     459     raise errors.VisaIOError(constants.VI_ERROR_RSRC_NFOUND)
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\tcpip.py:361, in Vxi11CoreClient.__init__(self, host, port, open_timeout)
#     358 prog, vers = vxi11.DEVICE_CORE_PROG, vxi11.DEVICE_CORE_VERS
#     360 if port is None:
# --> 361     rpc.TCPClient.__init__(self, host, prog, vers, open_timeout)
#     362 else:
#     363     # bypass the portmapper lookup and use the specified port instead
#     364     rpc.RawTCPClient.__init__(self, host, prog, vers, port, open_timeout)
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\protocols\rpc.py:823, in TCPClient.__init__(self, host, prog, vers, open_timeout)
#     822 def __init__(self, host, prog, vers, open_timeout=5000):
# --> 823     pmap = TCPPortMapperClient(host, open_timeout)
#     824     port = pmap.get_port((prog, vers, IPPROTO_TCP, 0))
#     825     pmap.close()
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\protocols\rpc.py:803, in TCPPortMapperClient.__init__(self, host, open_timeout)
#     802 def __init__(self, host, open_timeout=5000):
# --> 803     RawTCPClient.__init__(self, host, PMAP_PROG, PMAP_VERS, PMAP_PORT, open_timeout)
#     804     PartialPortMapperClient.__init__(self)
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\protocols\rpc.py:454, in RawTCPClient.__init__(self, host, prog, vers, port, open_timeout)
#     452 Client.__init__(self, host, prog, vers, port)
#     453 open_timeout = open_timeout if open_timeout is not None else 5000
# --> 454 self.connect(1e-3 * open_timeout)
#     455 # self.timeout defaults higher than the default 2 second VISA timeout,
#     456 # ensuring that VISA timeouts take precedence.
#     457 self.timeout = 4.0
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\protocols\rpc.py:487, in RawTCPClient.connect(self, timeout)
#     483 logger.debug(
#     484     "RawTCPClient: connecting to socket at (%s, %s)", self.host, self.port
#     485 )
#     486 self.sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# --> 487 if not _connect(self.sock, self.host, self.port, timeout):
#     488     raise RPCError("can't connect to server")
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\protocols\rpc.py:435, in _connect(sock, host, port, timeout)
#     432 finish_time = time.time() + timeout
#     433 while True:
#     434     # use select to wait for socket ready, max `select_timout` seconds
# --> 435     r, w, x = select.select([sock], [sock], [], select_timout)
#     436     if sock in r or sock in w:
#     437         return True
#
# KeyboardInterrupt:

# %%
is_connect_success = False 
while not is_connect_success:
    try:
        TSL = rm.open_resource("TCPIP::169.254.82.30::5000::SOCKET", read_termination="\r")
        print(TSL.query("*IDN?"))
        print("\x1b[0;92mTSL Connection established.\x1b[0m")
        is_connect_success = True
    except pyvisa.VisaIOError:
        print("Retrying...")
        time.sleep(0.5)

if TSL.query(":POW:STAT?") == "+0":
    TSL.write(":POW:STAT 1")
    time.sleep(0.5)
    print("Laser was off. Turning on laser.")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 while not is_connect_success:
#       3     try:
# ----> 4         TSL = rm.open_resource("TCPIP::169.254.82.30::5000::SOCKET", read_termination="\r")
#       5         print(TSL.query("*IDN?"))
#       6         print("\x1bTSL Connection established.\x1b")
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\highlevel.py:3292, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3286     if not present:
#    3287         raise ValueError(
#    3288             "%r is not a valid attribute for type %s"
#    3289             % (key, res.__class__.__name__)
#    3290         )
# -> 3292 res.open(access_mode, open_timeout)
#    3294 for key, value in kwargs.items():
#    3295     setattr(res, key, value)
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\resources\resource.py:281, in Resource.open(self, access_mode, open_timeout)
#     277 logger.debug("%s - opening ...", self._resource_name, extra=self._logging_extra)
#     278 with self._resource_manager.ignore_warning(
#     279     constants.StatusCode.success_device_not_present
#     280 ):
# --> 281     self.session, status = self._resource_manager.open_bare_resource(
#     282         self._resource_name, access_mode, open_timeout
#     283     )
#     285     if status == constants.StatusCode.success_device_not_present:
#     286         # The device was not ready when we opened the session.
#     287         # Now it gets five seconds more to become ready.
#     288         # Every 0.1 seconds we probe it with viClear.
#     289         start_time = time.time()
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa\highlevel.py:3217, in ResourceManager.open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3188 def open_bare_resource(
#    3189     self,
#    3190     resource_name: str,
#    3191     access_mode: constants.AccessModes = constants.AccessModes.no_lock,
#    3192     open_timeout: int = constants.VI_TMO_IMMEDIATE,
#    3193 ) -> Tuple[VISASession, StatusCode]:
#    3194     """Open the specified resource without wrapping into a class.
#    3195
#    3196     Parameters
#    (...)
#    3215
#    3216     """
# -> 3217     return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\highlevel.py:168, in PyVisaLibrary.open(self, session, resource_name, access_mode, open_timeout)
#     159     return (
#     160         VISASession(0),
#     161         self.handle_return_value(None, StatusCode.error_invalid_resource_name),
#     162     )
#     164 cls = sessions.Session.get_session_class(
#     165     parsed.interface_type_const, parsed.resource_class
#     166 )
# --> 168 sess = cls(session, resource_name, parsed, open_timeout)
#     170 return self._register(sess), StatusCode.success
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\sessions.py:322, in Session.__init__(self, resource_manager_session, resource_name, parsed, open_timeout)
#     319 default_timeout = attributes.AttributesByID[attr].default
#     320 self.set_attribute(attr, default_timeout)
# --> 322 self.after_parsing()
#
# File c:\Users\groov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvisa_py\tcpip.py:1061, in TCPIPSocketSession.after_parsing(self)
#    1059 if ret_status != StatusCode.success:
#    1060     self.close()
# -> 1061     raise Exception("could not connect: {0}".format(str(ret_status)))
#    1063 self.max_recv_size = 4096
#    1064 # This buffer is used to store the bytes that appeared after
#    1065 # termination char
#
# Exception: could not connect: -1073807339

# %%
def getData(DSO, channel=2):
    DSO.write(f":WAV:SOUR CHAN{int(channel)}")
    DSO.write(":WAV:POINTS 5500000")
    sRange = DSO.query("WAV:PRE?")
    lRange = sRange.split(",")
    # <format 16-bit NR1>, <type 16-bit NR1>, <points 32-bit NR1>, <count 32-bit NR1>,
    # <xincrement 64-bit floating point NR3>, <xorigin 64-bit floating point NR3>,
    # <xreference 32-bit NR1>,
    # <yincrement 32-bit floating point NR3>, <yorigin 32-bit floating point NR3>,
    # <yreference 32-bit NR1>
    # iStep = 256 if int(lRange[0])==0 else 65536
    # pts = int(lRange[2])
    dt = float(lRange[4])
    gain = float(lRange[7])
    y_offs = float(lRange[8])
    y_offs_byte = int(lRange[9])
    # get data as i16, convert to numpy array
    DSO.write("WAV:DATA?")
    sHead0 = DSO.read_bytes(count=10)
    # strip header to find # of points
    i0 = sHead0.find(b"#")
    nDig = int(chr(sHead0[i0 + 1]))  # [i0+1:i0+2])
    nByte = int((sHead0[i0 + 2 : i0 + 2 + nDig]))
    # read data, including final line feed
    sData = DSO.read_bytes(count=1 + nByte)
    # get data to numpy array
    vData = np.frombuffer(sData[:-1], dtype="uint8")
    data_arr = gain * (vData) + y_offs - gain * (y_offs_byte)
    time_arr = np.linspace(0, data_arr.size, data_arr.size) * dt
    # time.sleep(5)

    return data_arr, time_arr

# %%
TSL.query("TRIG:OUTP:STEP?")
# Out:
# '+1.00000000E-011'

# %%
WAV_START = 1480
WAV_END = 1640

# %%
TSL.write("WAV:SWE 0")
time.sleep(0.5)
TSL.write(F"WAV:SWE:STAR {WAV_START}E-9")
time.sleep(0.1)
TSL.write(F"WAV:SWE:STOP {WAV_END}E-9")
time.sleep(0.1)
TSL.write("WAV:SWE 1")
time.sleep(0.1)

# %%
time_range = 10
time_pos = 4
DSO.write(f":TIM:RANG {time_range}")
time.sleep(0.1)
DSO.write(f":TIM:POS {time_pos}")
time.sleep(0.1)
DSO.write("SING")
time.sleep(0.1)

# %%
time.sleep(2)
TSL.write(":TRIG:INP:SOFT")
time.sleep(time_range*1.1)

# %%
data_arr, time_arr = getData(DSO, channel=1)
time.sleep(0.1)
clock_arr, time_arr = getData(DSO, channel=2)
time.sleep(0.1)

# %%
plt.plot(time_arr, data_arr)
plt.show()

# %%
plt.plot(time_arr, clock_arr)
plt.show()

# %%
# start_idx = np.where(clock_arr>4)[0][0]
# end_idx = np.where(clock_arr>4)[0][-1]
start_idx = np.where(clock_arr > 0.5)[0][0]
end_idx = np.where(clock_arr > 0.5)[0][-1]

# %%
time_arr_cut = time_arr[start_idx:end_idx]
data_arr_cut = data_arr[start_idx:end_idx]
clock_arr_cut = clock_arr[start_idx:end_idx]

# %%
# wav_arr = np.linspace(1600, 1500, time_arr_cut.size)
# wav_arr = np.linspace(1500, 1600, time_arr_cut.size)
wav_arr = np.linspace(WAV_START, WAV_END, time_arr_cut.size)

# %%
chip_name = f"{CHIP_ID} {FEATURE_ID}"

# %%
plt.close()
plt.figure(figsize=(16, 10))
plt.plot(wav_arr, data_arr_cut * 10 ** (PM_RANGE / 10) * 1e-3)
plt.grid()
plt.xlabel("wavelength (nm)")
plt.ylabel("power (W)")
plt.ylim(0, None)
# plt.title(f'ESO reflection 1500-1600nm, faster sweep speed')
plt.title(f"{chip_name} transmission")
plt.annotate(
    f"Power meter range: {PM_RANGE} dBm",
    (0.15, 0.75),
    xycoords="axes fraction",
    alpha=0.6,
    fontsize=12,
    fontfamily="monospace",
)
plt.show()

# %%
plt.close()
plt.figure(figsize=(16, 10))
plt.plot(wav_arr, data_arr_cut * 10 ** (PM_RANGE / 10) * 1e-3)
plt.grid()
plt.xlabel("wavelength (nm)")
plt.ylabel("power (W)")
# plt.title(f'ESO reflection 1500-1600nm, faster sweep speed')
plt.title(f"{chip_name} transmission")
plt.annotate(
    f"Power meter range: {PM_RANGE} dBm",
    (0.15, 0.75),
    xycoords="axes fraction",
    alpha=0.6,
    fontsize=12,
    fontfamily="monospace",
)
plt.show()

# %%
plt.close()
plt.figure(figsize=(16, 10))
watt = list(data_arr_cut * 10 ** (PM_RANGE / 10) * 1e-3)
dBm = list(map(lambda x: math.log10(x) * 10 + 30, watt))
plt.plot(wav_arr, dBm)
plt.grid()
plt.xlabel("wavelength (nm)")
plt.ylabel("power (dBm)")
# plt.title(f'ESO reflection 1500-1600nm, faster sweep speed')
plt.title(f"{chip_name} transmission")
plt.annotate(
    f"Power meter range: {PM_RANGE} dBm",
    (0.15, 0.75),
    xycoords="axes fraction",
    alpha=0.6,
    fontsize=12,
    fontfamily="monospace",
)
plt.show()

# %%
plt.close()
plt.plot(wav_arr, data_arr_cut)
plt.grid()
plt.xlabel("wavelength (nm)")
plt.ylabel("voltage (V)")
plt.title(f"{chip_name} transmission")
plt.annotate(
    f"Power meter range: {PM_RANGE} dBm",
    (0.15, 0.75),
    xycoords="axes fraction",
    alpha=0.6,
    fontsize=12,
    fontfamily="monospace",
)
plt.gcf().set_dpi(200)
plt.show()

# %%
# np.savez(f'20240606_ESO_Reflection_50nms.npz', time_arr=time_arr, data_arr=data_arr, clock_arr=clock_arr, wav_arr=wav_arr, time_arr_cut=time_arr_cut, data_arr_cut=data_arr_cut, chip_name=chip_name, PM_RANGE=PM_RANGE)
np.savez(
    f"{CHIP_ID}_{FEATURE_ID}.npz",
    time_arr=time_arr,
    data_arr=data_arr,
    clock_arr=clock_arr,
    wav_arr=wav_arr,
    time_arr_cut=time_arr_cut,
    data_arr_cut=data_arr_cut,
    chip_name=chip_name,
    PM_RANGE=PM_RANGE,
)

# %%
TSL.write("WAV:SWE 0")
# Out:
# 11

# %%
TSL.write("WAV 1520nm")
# Out:
# 12

# %%
# if TSL.query(":POW:STAT?") == "+1":
#     TSL.write(":POW:STAT 0") # Turn off laser
TSL.close()
DSO.close()
del TSL
del DSO
